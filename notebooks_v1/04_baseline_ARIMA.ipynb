# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os 
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tools.sm_exceptions import ConvergenceWarning

import warnings
warnings.filterwarnings("ignore", message="Non-stationary starting autoregressive parameters found")
warnings.filterwarnings("ignore", message="Non-invertible starting MA parameters found")

from config import BASELINE_MODEL_DIR
from data_utils import load_data, get_date_columns, check_stationarity
from plot_utils import plot_stacked_time_series

# %%
data = load_data(transpose=True, remove_inactive_articles=True)
date_columns = get_date_columns(data)

# %%
data.shape
# Out:
# (803, 115084)

# %%
sampled_pages = data.sample(n=50, axis=1, random_state=130)

sampled_pages.head()
# Out:
# page        Sarah_Silverman_en.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                             5153.0
# 2015-07-02                                             5113.0
# 2015-07-03                                             5354.0
# 2015-07-04                                             4937.0
# 2015-07-05                                             5370.0
#
# page        Mario_Götze_es.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                              747.0
# 2015-07-02                                              703.0
# 2015-07-03                                              546.0
# 2015-07-04                                              915.0
# 2015-07-05                                             1061.0
#
# page        Chris_Rock_en.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                             3193.0
# 2015-07-02                                             3737.0
# 2015-07-03                                             3605.0
# 2015-07-04                                             3412.0
# 2015-07-05                                             3455.0
#
# page        ポケットモンスター_(劇場版)_ja.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                              880.0
# 2015-07-02                                              945.0
# 2015-07-03                                             1196.0
# 2015-07-04                                             1284.0
# 2015-07-05                                             1430.0
#
# page        B-52_(航空機)_ja.wikipedia.org_all-access_spider  \
# 2015-07-01                                           16.0
# 2015-07-02                                            7.0
# 2015-07-03                                           14.0
# 2015-07-04                                           10.0
# 2015-07-05                                           11.0
#
# page        慈禧太后_zh.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                                        271.0
# 2015-07-02                                        331.0
# 2015-07-03                                        303.0
# 2015-07-04                                        271.0
# 2015-07-05                                        369.0
#
# page        List_of_radars_en.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                              290.0
# 2015-07-02                                              260.0
# 2015-07-03                                              197.0
# 2015-07-04                                              225.0
# 2015-07-05                                              186.0
#
# page        おかもとまり_ja.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                                          340.0
# 2015-07-02                                          276.0
# 2015-07-03                                          234.0
# 2015-07-04                                          255.0
# 2015-07-05                                          214.0
#
# page        Сименс_(единица_измерения)_ru.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                               59.0
# 2015-07-02                                               65.0
# 2015-07-03                                               60.0
# 2015-07-04                                               42.0
# 2015-07-05                                               37.0
#
# page        ホキ_ja.wikipedia.org_desktop_all-agents  ...  \
# 2015-07-01                                   143.0  ...
# 2015-07-02                                   122.0  ...
# 2015-07-03                                   150.0  ...
# 2015-07-04                                    64.0  ...
# 2015-07-05                                    44.0  ...
#
# page        Radiohead_fr.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                             259.0
# 2015-07-02                                             288.0
# 2015-07-03                                             275.0
# 2015-07-04                                             303.0
# 2015-07-05                                             309.0
#
# page        Urknall_de.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                                           288.0
# 2015-07-02                                           322.0
# 2015-07-03                                           335.0
# 2015-07-04                                           422.0
# 2015-07-05                                           472.0
#
# page        Memento_(film)_en.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                             2671.0
# 2015-07-02                                             2440.0
# 2015-07-03                                             2345.0
# 2015-07-04                                             2550.0
# 2015-07-05                                             2803.0
#
# page        青山テルマ_ja.wikipedia.org_all-access_spider  \
# 2015-07-01                                       8.0
# 2015-07-02                                       3.0
# 2015-07-03                                       2.0
# 2015-07-04                                       4.0
# 2015-07-05                                       3.0
#
# page        Berserk_(manga)_en.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                             1592.0
# 2015-07-02                                             1551.0
# 2015-07-03                                             1419.0
# 2015-07-04                                             1375.0
# 2015-07-05                                             1488.0
#
# page        Иванова,_Анастасия_Семёновна_ru.wikipedia.org_mobile-web_all-agents  \
# 2015-07-01                                               71.0
# 2015-07-02                                               73.0
# 2015-07-03                                               73.0
# 2015-07-04                                               63.0
# 2015-07-05                                               68.0
#
# page        Manual:Importing_XML_dumps_www.mediawiki.org_desktop_all-agents  \
# 2015-07-01                                               87.0
# 2015-07-02                                               88.0
# 2015-07-03                                               72.0
# 2015-07-04                                               66.0
# 2015-07-05                                               80.0
#
# page        Alexander_Bommes_de.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                              185.0
# 2015-07-02                                              179.0
# 2015-07-03                                              445.0
# 2015-07-04                                              303.0
# 2015-07-05                                              114.0
#
# page        Milchstraße_de.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                              885.0
# 2015-07-02                                              819.0
# 2015-07-03                                              817.0
# 2015-07-04                                              759.0
# 2015-07-05                                             1037.0
#
# page        MediaWiki_1.26_www.mediawiki.org_desktop_all-agents
# 2015-07-01                                               22.0
# 2015-07-02                                               29.0
# 2015-07-03                                               27.0
# 2015-07-04                                               10.0
# 2015-07-05                                               10.0
#
# [5 rows x 50 columns]

# %%
plot_stacked_time_series(sampled_pages, sampled_pages.columns, offset_factor=0.09, legend=False)

# %% [markdown]
# ### Baseline ARIMA

# %%
def fit_arima(series, p, d, q, exog=None):
    model = ARIMA(series, exog=exog, order=(p, d, q))
    try:
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=ConvergenceWarning)
            fitted_model = model.fit()
    except Exception as e:
        print(f"Fitting ARIMA({p},{d},{q}) failed with default start parameters: {e}")
        # Retry with initial parameters set to zero
        fitted_model = model.fit(start_params=[0] * (p + q))
    return fitted_model


def find_best_arima_model(time_series, p_values, d_values, q_values, exog=None):
    best_aic = np.inf
    best_order = None
    best_model = None

    for p in p_values:
        for d in d_values:
            for q in q_values:
                try:
                    model = fit_arima(time_series, p, d, q, exog)
                    if model.aic < best_aic:
                        best_aic = model.aic
                        best_order = (p, d, q)
                        best_model = model
                except Exception as e:
                    print(f"Failed to fit ARIMA({p},{d},{q}): {str(e)}")
    
    return {"order": best_order, "model": best_model, "aic": best_aic}

# %%
def get_time_series_and_exog(data, page_name):
    time_series = data[page_name]
    time_series = time_series.asfreq('D')
    day_of_week = pd.to_datetime(time_series.index).dayofweek
    exog = pd.get_dummies(day_of_week, prefix='dow').astype(int)

    exog.index = time_series.index
    
    return time_series, exog

def train_test_split(series, exog, test_size):
    train = series[:-test_size]
    test = series[-test_size:]
    train_exog = exog[:-test_size]
    test_exog = exog[-test_size:]
    return train, test, train_exog, test_exog

# %%
def process_page(page_name, data, date_columns, p_values, d_values, q_values, test_size):
    print(f"Processing ARIMA models for page: {page_name}")
        
    # Get the time series data for the page
    time_series, exog = get_time_series_and_exog(data, page_name)
    
    # Skip the current iteration if no data was found
    if time_series is None:
        return

    # Determine if the series is stationary
    is_stationary = check_stationarity(time_series)

    # Adjust d_values based on stationarity
    adjusted_d_values = [0] if is_stationary else d_values

    # Split the data into training and testing sets
    train_series, test_series, train_exog, test_exog =  train_test_split(time_series, exog, test_size)

    # Find the best ARIMA model for the time series
    best_model_info = find_best_arima_model(train_series, p_values, adjusted_d_values, q_values, exog=train_exog)
    
    print(f"Best ARIMA model for {page_name}: Order={best_model_info['order']} AIC={best_model_info['aic']:.2f}")

    return best_model_info


def process_all_pages(data, date_columns, p_values, d_values, q_values, test_size):
    results = {}
    
    # Iterate over all unique pages in the DataFrame
    for page_name in data.columns:
        best_model_info = process_page(page_name, data, date_columns, p_values, d_values, q_values, test_size)
        if best_model_info is not None:
            results[page_name] = best_model_info

    return results

# %%
p_values = [0, 1, 2, 30]
d_values = [0, 1]
q_values = [0, 1, 2, 30]

test_size = 30
best_models_per_page = process_all_pages(sampled_pages, date_columns, p_values, d_values, q_values, test_size)
# Out:
# Processing ARIMA models for page: Sarah_Silverman_en.wikipedia.org_all-access_all-agents
# Best ARIMA model for Sarah_Silverman_en.wikipedia.org_all-access_all-agents: Order=(1, 0, 1) AIC=15247.81
# Processing ARIMA models for page: Mario_Götze_es.wikipedia.org_all-access_all-agents
# Best ARIMA model for Mario_Götze_es.wikipedia.org_all-access_all-agents: Order=(1, 0, 2) AIC=11779.54
# Processing ARIMA models for page: Chris_Rock_en.wikipedia.org_all-access_all-agents
# Best ARIMA model for Chris_Rock_en.wikipedia.org_all-access_all-agents: Order=(2, 0, 1) AIC=15910.25
# Processing ARIMA models for page: ポケットモンスター_(劇場版)_ja.wikipedia.org_all-access_all-agents
# Best ARIMA model for ポケットモンスター_(劇場版)_ja.wikipedia.org_all-access_all-agents: Order=(2, 0, 1) AIC=11256.27
# Processing ARIMA models for page: B-52_(航空機)_ja.wikipedia.org_all-access_spider
# Best ARIMA model for B-52_(航空機)_ja.wikipedia.org_all-access_spider: Order=(1, 0, 0) AIC=11551.16
# Processing ARIMA models for page: 慈禧太后_zh.wikipedia.org_mobile-web_all-agents
# Best ARIMA model for 慈禧太后_zh.wikipedia.org_mobile-web_all-agents: Order=(0, 0, 30) AIC=9246.74
# Processing ARIMA models for page: List_of_radars_en.wikipedia.org_all-access_all-agents
# Best ARIMA model for List_of_radars_en.wikipedia.org_all-access_all-agents: Order=(1, 0, 1) AIC=7800.77
# Processing ARIMA models for page: おかもとまり_ja.wikipedia.org_mobile-web_all-agents
# Best ARIMA model for おかもとまり_ja.wikipedia.org_mobile-web_all-agents: Order=(30, 0, 0) AIC=13115.90
# Processing ARIMA models for page: Сименс_(единица_измерения)_ru.wikipedia.org_all-access_all-agents
# Best ARIMA model for Сименс_(единица_измерения)_ru.wikipedia.org_all-access_all-agents: Order=(1, 0, 0) AIC=16657.22
# Processing ARIMA models for page: ホキ_ja.wikipedia.org_desktop_all-agents
# Best ARIMA model for ホキ_ja.wikipedia.org_desktop_all-agents: Order=(0, 0, 0) AIC=12874.90
# Processing ARIMA models for page: Star_Trek_en.wikipedia.org_desktop_all-agents
# Best ARIMA model for Star_Trek_en.wikipedia.org_desktop_all-agents: Order=(1, 0, 2) AIC=12920.19
# Processing ARIMA models for page: Methylphenidat_de.wikipedia.org_desktop_all-agents
# Best ARIMA model for Methylphenidat_de.wikipedia.org_desktop_all-agents: Order=(0, 0, 0) AIC=13357.12
# Processing ARIMA models for page: América_del_Norte_es.wikipedia.org_all-access_spider
# Best ARIMA model for América_del_Norte_es.wikipedia.org_all-access_spider: Order=(2, 0, 2) AIC=7859.66
# Processing ARIMA models for page: 通奸_zh.wikipedia.org_all-access_all-agents
# Best ARIMA model for 通奸_zh.wikipedia.org_all-access_all-agents: Order=(30, 0, 30) AIC=138.00
# Processing ARIMA models for page: 黃埔站_(香港)_zh.wikipedia.org_all-access_spider
# Best ARIMA model for 黃埔站_(香港)_zh.wikipedia.org_all-access_spider: Order=(1, 0, 30) AIC=6973.17
# Processing ARIMA models for page: Литвиненко,_Александр_Вальтерович_ru.wikipedia.org_desktop_all-agents
# Best ARIMA model for Литвиненко,_Александр_Вальтерович_ru.wikipedia.org_desktop_all-agents: Order=(1, 0, 2) AIC=13688.79
# Processing ARIMA models for page: Рейнольдс,_Райан_ru.wikipedia.org_all-access_all-agents
# Best ARIMA model for Рейнольдс,_Райан_ru.wikipedia.org_all-access_all-agents: Order=(30, 0, 1) AIC=13498.43
# Processing ARIMA models for page: As_One_zh.wikipedia.org_all-access_all-agents
# Best ARIMA model for As_One_zh.wikipedia.org_all-access_all-agents: Order=(2, 0, 1) AIC=10937.14
# Processing ARIMA models for page: Category:Sex_commons.wikimedia.org_all-access_all-agents
# Best ARIMA model for Category:Sex_commons.wikimedia.org_all-access_all-agents: Order=(2, 0, 2) AIC=8791.67
# Processing ARIMA models for page: File:Transparent.png_commons.wikimedia.org_all-access_spider
# Best ARIMA model for File:Transparent.png_commons.wikimedia.org_all-access_spider: Order=(30, 0, 0) AIC=3788.53
# Processing ARIMA models for page: Final_Fantasy_XV_fr.wikipedia.org_all-access_spider
# Best ARIMA model for Final_Fantasy_XV_fr.wikipedia.org_all-access_spider: Order=(1, 0, 2) AIC=6380.67
# Processing ARIMA models for page: Kris_Bryant_en.wikipedia.org_all-access_spider
# Best ARIMA model for Kris_Bryant_en.wikipedia.org_all-access_spider: Order=(0, 0, 30) AIC=8433.51
# Processing ARIMA models for page: 観月ありさ_ja.wikipedia.org_all-access_all-agents
# Best ARIMA model for 観月ありさ_ja.wikipedia.org_all-access_all-agents: Order=(1, 0, 2) AIC=14334.15
# Processing ARIMA models for page: Левенгук,_Антони_ван_ru.wikipedia.org_desktop_all-agents
# Best ARIMA model for Левенгук,_Антони_ван_ru.wikipedia.org_desktop_all-agents: Order=(1, 0, 0) AIC=14909.54
# Processing ARIMA models for page: Табаков,_Олег_Павлович_ru.wikipedia.org_all-access_spider
# Best ARIMA model for Табаков,_Олег_Павлович_ru.wikipedia.org_all-access_spider: Order=(1, 0, 2) AIC=7357.34
# Processing ARIMA models for page: Frédéric_Prinz_von_Anhalt_en.wikipedia.org_all-access_spider
# Best ARIMA model for Frédéric_Prinz_von_Anhalt_en.wikipedia.org_all-access_spider: Order=(1, 0, 2) AIC=6709.95
# Processing ARIMA models for page: Medio_rural_es.wikipedia.org_all-access_spider
# Best ARIMA model for Medio_rural_es.wikipedia.org_all-access_spider: Order=(1, 0, 1) AIC=6298.38
# Processing ARIMA models for page: Turkmenistan_de.wikipedia.org_desktop_all-agents
# Best ARIMA model for Turkmenistan_de.wikipedia.org_desktop_all-agents: Order=(1, 0, 1) AIC=11809.96
# Processing ARIMA models for page: 石田純一_ja.wikipedia.org_desktop_all-agents
# Best ARIMA model for 石田純一_ja.wikipedia.org_desktop_all-agents: Order=(2, 0, 2) AIC=13764.74
# Processing ARIMA models for page: William_Shakespeare_de.wikipedia.org_all-access_all-agents
# Best ARIMA model for William_Shakespeare_de.wikipedia.org_all-access_all-agents: Order=(2, 0, 1) AIC=14405.44
# Processing ARIMA models for page: 椎名法子_ja.wikipedia.org_all-access_all-agents
# Best ARIMA model for 椎名法子_ja.wikipedia.org_all-access_all-agents: Order=(0, 0, 30) AIC=13434.06
# Processing ARIMA models for page: All_your_base_are_belong_to_us_zh.wikipedia.org_desktop_all-agents
# Best ARIMA model for All_your_base_are_belong_to_us_zh.wikipedia.org_desktop_all-agents: Order=(1, 0, 30) AIC=11362.57
# Processing ARIMA models for page: Mo_Farah_en.wikipedia.org_all-access_spider
# Best ARIMA model for Mo_Farah_en.wikipedia.org_all-access_spider: Order=(30, 0, 0) AIC=8721.64
# Processing ARIMA models for page: 郭東延_zh.wikipedia.org_desktop_all-agents
# Best ARIMA model for 郭東延_zh.wikipedia.org_desktop_all-agents: Order=(1, 1, 30) AIC=8659.10
# Processing ARIMA models for page: México_prehispánico_es.wikipedia.org_all-access_spider
# Best ARIMA model for México_prehispánico_es.wikipedia.org_all-access_spider: Order=(2, 0, 1) AIC=6131.59
# Processing ARIMA models for page: 澳門_zh.wikipedia.org_desktop_all-agents
# Best ARIMA model for 澳門_zh.wikipedia.org_desktop_all-agents: Order=(1, 0, 2) AIC=9170.36
# Processing ARIMA models for page: File:Bundesarchiv_Bild_183-08778-0001,_Dresden,_Tote_nach_Bombenangriff.jpg_commons.wikimedia.org_mobile-web_all-agents
# Best ARIMA model for File:Bundesarchiv_Bild_183-08778-0001,_Dresden,_Tote_nach_Bombenangriff.jpg_commons.wikimedia.org_mobile-web_all-agents: Order=(1, 0, 1) AIC=7748.21
# Processing ARIMA models for page: 美少女戰士Crystal_zh.wikipedia.org_all-access_spider
# Best ARIMA model for 美少女戰士Crystal_zh.wikipedia.org_all-access_spider: Order=(2, 0, 1) AIC=6788.85
# Processing ARIMA models for page: Atentado_a_la_AMIA_es.wikipedia.org_all-access_all-agents
# Best ARIMA model for Atentado_a_la_AMIA_es.wikipedia.org_all-access_all-agents: Order=(1, 0, 30) AIC=12880.44
# Processing ARIMA models for page: 三種の神器_ja.wikipedia.org_all-access_all-agents
# Best ARIMA model for 三種の神器_ja.wikipedia.org_all-access_all-agents: Order=(1, 0, 2) AIC=12902.69
# Processing ARIMA models for page: Radiohead_fr.wikipedia.org_all-access_all-agents
# 2015-07-03                                               73.0
# 2015-07-04                                               63.0
# 2015-07-05                                               68.0
# ...                                                       ...
# 2017-09-06                                              115.0
# 2017-09-07                                              106.0
# 2017-09-08                                               85.0
# 2017-09-09                                               64.0
# 2017-09-10                                              101.0
#
# page        Manual:Importing_XML_dumps_www.mediawiki.org_desktop_all-agents  \
# 2015-07-01                                               87.0
# 2015-07-02                                               88.0
# 2015-07-03                                               72.0
# 2015-07-04                                               66.0
# 2015-07-05                                               80.0
# ...                                                       ...
# 2017-09-06                                               80.0
# 2017-09-07                                               59.0
# 2017-09-08                                               60.0
# 2017-09-09                                               39.0
# 2017-09-10                                               37.0
#
# page        Alexander_Bommes_de.wikipedia.org_desktop_all-agents  \
# 2015-07-01                                              185.0
# 2015-07-02                                              179.0
# 2015-07-03                                              445.0
# 2015-07-04                                              303.0
# 2015-07-05                                              114.0
# ...                                                       ...
# 2017-09-06                                              128.0
# 2017-09-07                                              131.0
# 2017-09-08                                              127.0
# 2017-09-09                                               64.0
# 2017-09-10                                              117.0
#
# page        Milchstraße_de.wikipedia.org_all-access_all-agents  \
# 2015-07-01                                              885.0
# 2015-07-02                                              819.0
# 2015-07-03                                              817.0
# 2015-07-04                                              759.0
# 2015-07-05                                             1037.0
# ...                                                       ...
# 2017-09-06                                             1017.0
# 2017-09-07                                              879.0
# 2017-09-08                                              668.0
# 2017-09-09                                              760.0
# 2017-09-10                                              889.0
#
# page        MediaWiki_1.26_www.mediawiki.org_desktop_all-agents
# 2015-07-01                                               22.0
# 2015-07-02                                               29.0
# 2015-07-03                                               27.0
# 2015-07-04                                               10.0
# 2015-07-05                                               10.0
# ...                                                       ...
# 2017-09-06                                               24.0
# 2017-09-07                                               14.0
# 2017-09-08                                               20.0
# 2017-09-09                                               12.0
# 2017-09-10                                                3.0
#
# [803 rows x 50 columns]

# %%
len(best_models_per_page)
# Out:
# 50

# %%
os.makedirs(BASELINE_MODEL_DIR, exist_ok=True)

# Save each model separately
for page, model_info in best_models_per_page.items():
    model = model_info['model']
    file_name = f"{page.replace('/', '_').replace(':', '_')}.pkl" 
    file_path = os.path.join(BASELINE_MODEL_DIR, file_name)
    
    with open(file_path, 'wb') as file:
        pickle.dump(model, file)

print("Models have been successfully saved.")
# Out:
# Models have been successfully saved.

# %%
def smape(actual, forecast):
    return 100 * np.mean(2 * np.abs(forecast - actual) / (np.abs(actual) + np.abs(forecast)))


def forecast_test(model, test_series, test_exog):
    forecast = model.get_forecast(steps=len(test_series), exog=test_exog)
    forecast_index = pd.date_range(start=test_series.index[0], periods=len(test_series), freq='D')
    forecast_series = pd.Series(forecast.predicted_mean, index=forecast_index)
    return forecast_series

def evaluate_model_performance(model, data, page_name, test_size):
    
    time_series, exog = get_time_series_and_exog(data, page_name)
    train_series, test_series, train_exog, test_exog = train_test_split(time_series, exog, test_size)
    forecast_series = forecast_test(model, test_series, test_exog)
    sMAPE_value = smape(test_series, forecast_series)
    return sMAPE_value

def evaluate_all_models(best_models_per_page, data, test_size=30):
    page_to_sMAPE = {}
    for page_name, best_model_dict in best_models_per_page.items():
        model = best_model_dict['model']
        sMAPE = evaluate_model_performance(model, data, page_name, test_size)
        page_to_sMAPE[page_name] = sMAPE
    return page_to_sMAPE

# %%
page_to_sMAPE = evaluate_all_models(best_models_per_page, sampled_pages)

page_w_min_sMAPE = None
page_w_max_sMAPE = None
min_sMAPE = np.inf
max_sMAPE = 0
total = 0
for page, sMAPE in page_to_sMAPE.items():
    total += sMAPE
    if sMAPE < min_sMAPE:
        page_w_min_sMAPE = page
        min_sMAPE = sMAPE

    if sMAPE > max_sMAPE:
        page_w_max_sMAPE = page
        max_sMAPE = sMAPE

print(f'Average sMAPE is {total / len(page_to_sMAPE):.2f}%')
# Out:
# Average sMAPE is 49.75%

# %%
def check_residuals(model):
    residuals = model.resid
    fig, ax = plt.subplots(1, 2, figsize=(15, 6))
    residuals.plot(ax=ax[0], title="Residuals")
    residuals.plot(kind='kde', ax=ax[1], title="Density")
    plt.show()
    
def plot_forecast_vs_actual(train_series, test_series, train_exog, test_exog, model, plot_only_test=False):
    fig, ax = plt.subplots(figsize=(14, 7))
    
    if not plot_only_test:
        ax.plot(train_series, label='Train', color='blue', linewidth=1)
        # In-sample forecast
        in_sample_forecast = model.fittedvalues
        ax.plot(in_sample_forecast, label='In-sample Forecast', color='green', linestyle='--', linewidth=2)

    ax.plot(test_series, label='Test', color='orange', linewidth=1)
    # Out-of-sample forecast
    forecast = model.get_forecast(steps=len(test_series), exog=test_exog)
    forecast_index = pd.date_range(start=test_series.index[0], periods=len(test_series), freq='D')
    forecast_series = pd.Series(forecast.predicted_mean, index=forecast_index)
    ax.plot(forecast_series, label='Out-of-sample Forecast', color='red', linestyle='--', linewidth=2)

    sMAPE_value = smape(test_series, forecast_series)
    print(f'sMAPE: {sMAPE_value:.2f}%')
    
    # Adding titles and labels
    ax.set_title('Actual vs Forecasted Values', fontsize=16)
    ax.set_xlabel('Date', fontsize=14)
    ax.set_ylabel('Page Views', fontsize=14)
    
    # Adding legend
    ax.legend(loc='upper left', fontsize=12)
    
    # Adding grid for better readability
    ax.grid(True)
    
    # Improving the appearance
    plt.tight_layout()
    
    plt.show()

def plot_model_forecast(data, best_models_per_page, date_columns, page_name, test_size):
    if page_name not in best_models_per_page:
        print(f"No model found for page: {page_name}")
        return
    
    best_model_info = best_models_per_page[page_name]
    model = best_model_info['model']
    
    time_series, exog = get_time_series_and_exog(data, page_name)
    
    if time_series is not None:
        train_series, test_series, train_exog, test_exog = train_test_split(time_series, exog, test_size)
        plot_forecast_vs_actual(train_series, test_series, train_exog, test_exog, model, plot_only_test=True)
        check_residuals(model)

# %% [markdown]
# ### Page with Minimum sMAPE

# %%
plot_model_forecast(sampled_pages, best_models_per_page, date_columns, page_w_min_sMAPE, test_size)
# Out:
# sMAPE: 9.85%

# %% [markdown]
# ### Page with Maximum sMAPE

# %%
plot_model_forecast(sampled_pages, best_models_per_page, date_columns, page_w_max_sMAPE, test_size)
# Out:
# sMAPE: 144.31%

# %%
sampled_pages.to_csv(os.path.join(BASELINE_MODEL_DIR, 'data.csv'), index_label='date')
